# %% [markdown]
# # Matching users as client of EvasionBuilder and MatchingUsers modules

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# %matplotlib inline
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from importlib import reload
import datetime as dt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from Utils import TransantiagoConstants
import EvasionBuilder

# %%
processed_evasion = EvasionBuilder.runCompleteProcess()
# Out:
# Original number of rows in complete evasion database is: 97373
# Number of duplicated rows in complete evasion database is: 6192
# Number of collapsed-duplicated rows in complete evasion database is: 3090
# Number of rows in complete evasion database without duplicated rows at all is: 91181
# Final number of rows in complete evasion database with collapsed duplicated rows is: 94271
# C:\Users\leoca_000\Anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\leoca_000\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# The only non-matched user_code services are:
# D06

# %% [markdown]
# * Processing complete evasion-ddbb

# %%
evasion_paradero = processed_evasion[processed_evasion['TP']=='P']
evasion_paradero_first = evasion_paradero[evasion_paradero['N_PUERTA']==1]

# %%
print('Number of rows in complete evasion database is: ' + str(len(processed_evasion.index)))
print('Number of rows in evasion in paradero database is: ' + str(len(evasion_paradero.index)))
print('Number of rows in evasion in paradero by first door database is: ' + str(len(evasion_paradero_first.index)))
# Out:
# Number of rows in complete evasion database is: 94271
# Number of rows in evasion in paradero database is: 92604
# Number of rows in evasion in paradero by first door database is: 33120

# %% [markdown]
# * Filtering dates not in common dates. DataFrame "common_dates_evasion" will be the final evasion DataFrame

# %%
common_dates = TransantiagoConstants.common_dates
common_dates_timestamp = [pd.to_datetime(x) for x in common_dates]
common_dates_evasion = evasion_paradero_first[evasion_paradero_first['FECHA'].isin(common_dates_timestamp)]

print('Number of rows in complete evasion database filtered by common_dates is: ' + str(len(common_dates_evasion.index))) #Remember to store the number.
# Out:
# Number of rows in complete evasion database filtered by common_dates is: 14632

# %% [markdown]
# * Building Etapas DataBase via <strong>DailyEtapasBuilder</strong> and matching users via <strong>MatchingUsers</strong>

# %%
#common_dates = ['2017-04-11']

# %%
import DailyEtapasBuilder

# %%
import MatchingUsers

# %%
summary_evasion_vs_mean = pd.DataFrame()

for date in common_dates:    
    etapas_builder = DailyEtapasBuilder.RunSilentlyDailyEtapasBuilderClass(date)
    etapas_builder.loadSimplifiedEtapas()
    etapas_builder.mergeTurnstileData()
    etapas_builder.cleanDataFrame()
    etapas_builder.sortDataFrame()
    etapas_builder.postProcessingSortedDataFrame()
    processed_sorted_df = etapas_builder.etapas_df  
    processed_sorted_df['sitio_subida'] = processed_sorted_df['sitio_subida'].str.replace("-", "")
    processed_sorted_df['sitio_subida'] = processed_sorted_df['sitio_subida'].str.replace(" ", "")
    
    processed_sorted_df['servicio_subida'] =  processed_sorted_df['servicio_subida'].str.replace('T','')
    processed_sorted_df['servicio_subida'] =  processed_sorted_df['servicio_subida'].str.split(' ').str[0]
    
    print('The number of rows in the original etapas database is: ' + str(len(processed_sorted_df.index)) + ' rows.' )
    #Filtering special cases.
    filtered_processed_sorted_df = processed_sorted_df[(processed_sorted_df['diferencia_tiempo_secs']<=20)|(processed_sorted_df['diferencia_tiempo_secs'].isnull())]
    print('The number of rows in the filtered (by special cases) etapas database is: '  + str(len(filtered_processed_sorted_df.index)) + ' rows.' )
    
    [evasion_by_date, patentes_by_date, servicios_by_date] = MatchingUsers.simplifyingEvasion(common_dates_evasion,date) #Getting patentes and servicios surveyed in date...
    
    clean_sorted_df = filtered_processed_sorted_df[(filtered_processed_sorted_df['sitio_subida'].isin(patentes_by_date))&(filtered_processed_sorted_df['servicio_subida'].isin(servicios_by_date))] #Filtering...
    clean_sorted_df = clean_sorted_df.reset_index(drop=True)
    print('The number of rows in the clean_sorted_df is: '  + str(len(clean_sorted_df.index)) + ' rows.' )

    clean_sorted_df_1 = MatchingUsers.appendingIdExpedicion(clean_sorted_df,'15 minutes') #Appending (ad-hoc) id expedicion.
    grouped_clean_sorted_df_1 = MatchingUsers.groupByEtapasDatabase(clean_sorted_df_1) #Grouping by 'sitio_subida','servicio_subida','idExpedicion','par_subida'
    grouped_clean_sorted_df_2 = MatchingUsers.appendingStartEndCuts(grouped_clean_sorted_df_1) #Computing start and end cuts.
    grouped_clean_sorted_df_3 = MatchingUsers.slicingEvasionDatabase(grouped_clean_sorted_df_2,evasion_by_date) #This is the final ddbb with full info.
    grouped_clean_sorted_df_4 = MatchingUsers.reMergeTurnstileData(grouped_clean_sorted_df_3)
    summary_evasion_vs_mean = pd.concat([summary_evasion_vs_mean,grouped_clean_sorted_df_4])
# Out:
# Not found in turnstile database: 1795630
# The number of rows in the original etapas database is: 2535246 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2473922 rows.
# The number of rows in the clean_sorted_df is: 2492 rows.
# Not found in turnstile database: 1832615
# The number of rows in the original etapas database is: 2591725 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2528203 rows.
# The number of rows in the clean_sorted_df is: 2842 rows.
# Not found in turnstile database: 1842842
# The number of rows in the original etapas database is: 2612985 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2549011 rows.
# The number of rows in the clean_sorted_df is: 9216 rows.
# Not found in turnstile database: 1821215
# The number of rows in the original etapas database is: 2589603 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2527375 rows.
# The number of rows in the clean_sorted_df is: 4701 rows.
# Not found in turnstile database: 1829611
# The number of rows in the original etapas database is: 2598131 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2533387 rows.
# The number of rows in the clean_sorted_df is: 11441 rows.
# Not found in turnstile database: 1889530
# The number of rows in the original etapas database is: 2678999 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2612442 rows.
# The number of rows in the clean_sorted_df is: 6967 rows.
# Not found in turnstile database: 1869904
# The number of rows in the original etapas database is: 2663162 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2596577 rows.
# The number of rows in the clean_sorted_df is: 12589 rows.
# Not found in turnstile database: 517700
# The number of rows in the original etapas database is: 803771 rows.
# The number of rows in the filtered (by special cases) etapas database is: 780989 rows.
# The number of rows in the clean_sorted_df is: 2779 rows.
# Not found in turnstile database: 1764405
# The number of rows in the original etapas database is: 2525338 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2460860 rows.
# The number of rows in the clean_sorted_df is: 13600 rows.
# Not found in turnstile database: 1680579
# The number of rows in the original etapas database is: 2390427 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2329429 rows.
# The number of rows in the clean_sorted_df is: 4828 rows.
# Not found in turnstile database: 1560500
# The number of rows in the original etapas database is: 2222618 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2165889 rows.
# The number of rows in the clean_sorted_df is: 3804 rows.
# Not found in turnstile database: 1598721
# The number of rows in the original etapas database is: 2272834 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2214895 rows.
# The number of rows in the clean_sorted_df is: 11979 rows.
# Not found in turnstile database: 1637796
# The number of rows in the original etapas database is: 2326044 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2267188 rows.
# The number of rows in the clean_sorted_df is: 11705 rows.
# Not found in turnstile database: 1876347
# The number of rows in the original etapas database is: 2679443 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2611154 rows.
# The number of rows in the clean_sorted_df is: 6606 rows.
# Not found in turnstile database: 1867643
# The number of rows in the original etapas database is: 2653409 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2585895 rows.
# The number of rows in the clean_sorted_df is: 5826 rows.
# Not found in turnstile database: 1873694
# The number of rows in the original etapas database is: 2668607 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2601271 rows.
# The number of rows in the clean_sorted_df is: 11349 rows.
# Not found in turnstile database: 1877006
# The number of rows in the original etapas database is: 2673767 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2607061 rows.
# The number of rows in the clean_sorted_df is: 11087 rows.
# Not found in turnstile database: 1842523
# The number of rows in the original etapas database is: 2636529 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2570665 rows.
# The number of rows in the clean_sorted_df is: 3990 rows.

# %%
print('The number of rows in the summary_evasion_vs_mean: '  + str(len(summary_evasion_vs_mean.index)) + ' rows.' )
# Out:
# The number of rows in the summary_evasion_vs_mean: 52049 rows.

# %%
summary_evasion_vs_mean.loc[:,'EVASION_RATE'] = summary_evasion_vs_mean.loc[:,'TOTAL_NO_VALIDAN']/summary_evasion_vs_mean.loc[:,'TOTAL_INGRESAN']

not_null_mean_summary = summary_evasion_vs_mean[summary_evasion_vs_mean['diferencia_tiempo_secs_mean'].notnull()]
not_null_mean_count_summary = not_null_mean_summary[not_null_mean_summary['EVASION_COUNT']>0]
not_null_mean_count_summary_no_turns = not_null_mean_count_summary[(not_null_mean_count_summary['SI_TORNIQUETE']==False)|((not_null_mean_count_summary['SI_TORNIQUETE']==True) & (not_null_mean_count_summary['t_subida_max']<=not_null_mean_count_summary['fecha_instalacion']))]

# %%
print('The number of rows in the not_null_mean_summary dataframe is: ' + str(len(not_null_mean_summary.index)) + ' rows.')
print('The number of rows in the not_null_mean_count_summary dataframe is: ' + str(len(not_null_mean_count_summary.index)) + ' rows.')
print('The number of rows in the not_null_mean_count_summary_no_turns dataframe is: ' + str(len(not_null_mean_count_summary_no_turns.index)) + ' rows.')
# Out:
# The number of rows in the not_null_mean_summary dataframe is: 25835 rows.
# The number of rows in the not_null_mean_count_summary dataframe is: 3656 rows.
# The number of rows in the not_null_mean_count_summary_no_turns dataframe is: 2811 rows.

# %%
fig_1, ax_1 = plt.subplots()

ax_1.scatter(not_null_mean_count_summary_no_turns['diferencia_tiempo_secs_mean'],not_null_mean_count_summary_no_turns['EVASION_RATE'])
ax_1.set_title('Evasion vs. Mean Time - No Turns, By Bus, Service, Stop, 20Secs')
ax_1.set_xlabel('Mean Time Interval [s]')
ax_1.set_ylabel('Evasion Rate [%]')

plt.savefig('C:/Users/leoca_000/Desktop/Evasion/03_report/02_Figs/9_20Secs_EvasionVsMeanTimeByBusByServiceByStop.pdf')

# %% [markdown]
# ### Analyzing - 20Secs

# %%
not_null_mean_count_summary_no_turns = not_null_mean_count_summary_no_turns.reset_index(drop=True)

# %% [markdown]
# * Obs. with diferencia_tiempo_secs_mean>=18

# %%
not_null_mean_count_summary_no_turns[not_null_mean_count_summary_no_turns['diferencia_tiempo_secs_mean']>=18]
# Out:
#      sitio_subida servicio_subida  idExpedicion      par_subida  \
# 228        BJFD69             508             4   L-32-19-10-OP
# 263        BJFR91             363             2    L-34-9-20-NS
# 317        CJRT79             454             6  T-31-134-SN-25
# 1078       CJRW86             360             4   L-33-59-55-PO
# 1113       CRXT55             B51            33   L-16-21-25-OP
# 1179       CJRX69             339            25    L-21-41-5-PO
# 1436       CJRS46             406             1  E-20-53-PO-105
# 1498       ZN4334             120            10  T-28-234-SN-10
# 1521       ZN5077             120            11  T-28-233-NS-25
# 1563       CJRV65             456            43    L-32-28-2-OP
# 1614       BFKC67             518             5  T-14-116-OP-70
# 1827       ZN4773             403             6  T-18-157-PO-50
# 1912       BJFW95             358            52   L-33-50-40-SN
# 1954       CJRK64             B51             9  T-17-136-PO-55
# 1973       CJRX76             457            12    L-33-84-5-OP
# 2380       CJRG41             F18            57   L-34-40-15-PO
# 2476       ZN4208             104            16  T-31-254-NS-30
# 2679       FLXV10             523            18  T-20-188-NS-10
#
#             t_subida_min        t_subida_max  t_subida_count  \
# 228  2017-03-15 10:32:48 2017-03-15 10:33:06               2
# 263  2017-03-15 10:09:37 2017-03-15 10:09:57               2
# 317  2017-03-15 17:02:51 2017-03-15 17:03:10               2
# 1078 2017-04-18 09:22:13 2017-04-18 09:22:33               2
# 1113 2017-04-18 14:59:29 2017-04-18 14:59:49               2
# 1179 2017-06-14 07:00:54 2017-06-14 07:01:13               2
# 1436 2017-07-11 07:45:29 2017-07-11 07:45:47               2
# 1498 2017-07-11 14:38:03 2017-07-11 14:38:23               2
# 1521 2017-07-11 08:03:52 2017-07-11 08:04:10               2
# 1563 2017-07-13 15:17:44 2017-07-13 15:18:03               2
# 1614 2017-07-18 12:36:34 2017-07-18 12:36:52               2
# 1827 2017-07-18 17:43:16 2017-07-18 17:48:02               2
# 1912 2017-07-19 16:59:54 2017-07-19 17:00:12               2
# 1954 2017-07-19 16:47:06 2017-07-19 16:47:25               2
# 1973 2017-07-19 12:16:10 2017-07-19 13:15:09               3
# 2380 2017-08-17 18:36:58 2017-08-17 18:37:18               2
# 2476 2017-08-17 19:49:36 2017-08-17 19:49:56               2
# 2679 2017-08-22 16:39:18 2017-08-22 16:39:38               2
#
#       diferencia_tiempo_secs_mean                   start_cut  \
# 228                          18.0         2017-03-15 10:32:41
# 263                          20.0  2017-03-15 10:09:01.500000
# 317                          19.0         2017-03-15 17:02:32
# 1078                         20.0  2017-04-18 09:21:56.500000
# 1113                         20.0  2017-04-18 14:58:59.500000
# 1179                         19.0  2017-06-14 06:59:47.500000
# 1436                         18.0         2017-07-11 07:44:29
# 1498                         20.0  2017-07-11 14:36:59.500000
# 1521                         18.0         2017-07-11 08:03:25
# 1563                         19.0         2017-07-13 15:17:14
# 1614                         18.0         2017-07-18 12:35:52
# 1827                         19.0         2017-07-18 17:42:45
# 1912                         18.0  2017-07-19 16:59:45.500000
# 1954                         19.0         2017-07-19 16:41:32
# 1973                         18.0         2017-07-19 12:15:40
# 2380                         20.0         2017-08-17 18:35:49
# 2476                         20.0         2017-08-17 19:45:19
# 2679                         20.0         2017-08-22 16:39:15
#
#                          end_cut  EVASION_COUNT  TOTAL_INGRESAN  \
# 228   2017-03-15 10:34:01.500000            1.0             2.0
# 263          2017-03-15 10:10:27            1.0             2.0
# 317   2017-03-15 17:04:12.500000            1.0             3.0
# 1078         2017-04-18 09:25:08            1.0             1.0
# 1113  2017-04-18 15:00:19.500000            1.0             2.0
# 1179  2017-06-14 07:01:42.500000            1.0             2.0
# 1436         2017-07-11 07:47:28            1.0             4.0
# 1498  2017-07-11 14:39:46.500000            2.0             7.0
# 1521  2017-07-11 08:05:27.500000            1.0             2.0
# 1563         2017-07-13 15:20:29            1.0             2.0
# 1614         2017-07-18 12:37:58            1.0             4.0
# 1827  2017-07-18 17:48:58.500000            1.0             7.0
# 1912         2017-07-19 17:00:42            1.0             5.0
# 1954         2017-07-19 16:49:33            1.0             2.0
# 1973         2017-07-19 12:47:49            8.0            20.0
# 2380         2017-08-17 18:38:06            2.0            12.0
# 2476  2017-08-17 19:50:54.500000            1.0             2.0
# 2679  2017-08-22 16:42:08.500000            1.0             2.0
#
#       TOTAL_NO_VALIDAN fecha_instalacion  SI_TORNIQUETE  SI_2017_TORNIQUETE  \
# 228                0.0               NaT          False               False
# 263                0.0               NaT          False               False
# 317                0.0               NaT          False               False
# 1078               0.0               NaT          False               False
# 1113               1.0               NaT          False               False
# 1179               0.0               NaT          False               False
# 1436               2.0               NaT          False               False
# 1498               4.0               NaT          False               False
# 1521               0.0               NaT          False               False
# 1563               0.0               NaT          False               False
# 1614               0.0               NaT          False               False
# 1827               0.0               NaT          False               False
# 1912               3.0               NaT          False               False
# 1954               0.0               NaT          False               False
# 1973               2.0               NaT          False               False
# 2380               9.0               NaT          False               False
# 2476               1.0               NaT          False               False
# 2679               1.0               NaT          False               False
#
#       EVASION_RATE
# 228       0.000000
# 263       0.000000
# 317       0.000000
# 1078      0.000000
# 1113      0.500000
# 1179      0.000000
# 1436      0.500000
# 1498      0.571429
# 1521      0.000000
# 1563      0.000000
# 1614      0.000000
# 1827      0.000000
# 1912      0.600000
# 1954      0.000000
# 1973      0.100000
# 2380      0.750000
# 2476      0.500000
# 2679      0.500000

# %% [markdown]
# * Row number 1973 is specially weird. Checking...

# %%
not_null_mean_count_summary_no_turns.loc[1973,:]
# Out:
# sitio_subida                                CJRX76
# servicio_subida                                457
# idExpedicion                                    12
# par_subida                            L-33-84-5-OP
# t_subida_min                   2017-07-19 12:16:10
# t_subida_max                   2017-07-19 13:15:09
# t_subida_count                                   3
# diferencia_tiempo_secs_mean                     18
# start_cut                      2017-07-19 12:15:40
# end_cut                        2017-07-19 12:47:49
# EVASION_COUNT                                    8
# TOTAL_INGRESAN                                  20
# TOTAL_NO_VALIDAN                                 2
# fecha_instalacion                              NaT
# SI_TORNIQUETE                                False
# SI_2017_TORNIQUETE                           False
# EVASION_RATE                                   0.1
# Name: 1973, dtype: object

# %%
date = '2017-07-19'
patente = 'CJRX-76'
servicio = '457'
paradero = 'L-33-84-5-OP'

# %%
etapas_builder = DailyEtapasBuilder.RunSilentlyDailyEtapasBuilderClass(date)
etapas_builder.loadSimplifiedEtapas()
etapas_builder.mergeTurnstileData()
etapas_builder.cleanDataFrame()
etapas_builder.sortDataFrame()
etapas_builder.postProcessingSortedDataFrame()
processed_sorted_df = etapas_builder.etapas_df
# Out:
# Not found in turnstile database: 1637796

# %%
processed_sorted_df = processed_sorted_df.reset_index(drop=True)

# %%
processed_sorted_df[(processed_sorted_df['sitio_subida']==patente)&(processed_sorted_df['par_subida']==paradero)]
# Out:
#            index          id  nviaje tipo_transporte            t_subida  \
# 1150630  1380146  2501161870       1             BUS 2017-07-19 07:16:08
# 1150698   688740   474307586       1             BUS 2017-07-19 09:32:16
# 1150768     9244    24186706       1             BUS 2017-07-19 11:22:12
# 1150793  1383987  2503728606       1             BUS 2017-07-19 12:16:10
# 1150794  1487788  2687844446       1             BUS 2017-07-19 12:16:28
# 1150821  1006350  1369948350       2             BUS 2017-07-19 13:15:09
# 1150856    73289    35127314       1             BUS 2017-07-19 14:15:24
# 1150903  1631751  2802915950       3             BUS 2017-07-19 16:10:01
# 1150904  1005065  1363693412       1             BUS 2017-07-19 16:10:03
# 1151026  2106611  3656517163       2             BUS 2017-07-19 19:29:59
# 1151027   887036   931720299       3             BUS 2017-07-19 19:30:14
# 1151085   873050   930184523       1             BUS 2017-07-19 22:57:23
#
#         servicio_subida    par_subida sitio_subida fecha_instalacion  \
# 1150630        T457 03I  L-33-84-5-OP      CJRX-76               NaT
# 1150698        T457 00I  L-33-84-5-OP      CJRX-76               NaT
# 1150768        T457 00I  L-33-84-5-OP      CJRX-76               NaT
# 1150793        T457 00I  L-33-84-5-OP      CJRX-76               NaT
# 1150794        T457 00I  L-33-84-5-OP      CJRX-76               NaT
# 1150821        T457 00I  L-33-84-5-OP      CJRX-76               NaT
# 1150856        T457 00I  L-33-84-5-OP      CJRX-76               NaT
# 1150903        T457 00I  L-33-84-5-OP      CJRX-76               NaT
# 1150904        T457 00I  L-33-84-5-OP      CJRX-76               NaT
# 1151026        T457 00I  L-33-84-5-OP      CJRX-76               NaT
# 1151027        T457 00I  L-33-84-5-OP      CJRX-76               NaT
# 1151085        T457 03I  L-33-84-5-OP      CJRX-76               NaT
#
#          mismo_paradero  misma_patente  mismo_servicio diferencia_tiempo  \
# 1150630           False           True            True               NaT
# 1150698           False           True           False               NaT
# 1150768           False           True           False               NaT
# 1150793           False           True           False               NaT
# 1150794            True           True            True          00:00:18
# 1150821           False           True            True               NaT
# 1150856           False           True           False               NaT
# 1150903           False           True           False               NaT
# 1150904            True           True            True          00:00:02
# 1151026           False           True           False               NaT
# 1151027            True           True            True          00:00:15
# 1151085           False           True            True               NaT
#
#          diferencia_tiempo_secs  si_torniquete  si_2017_torniquete
# 1150630                     NaN          False               False
# 1150698                     NaN          False               False
# 1150768                     NaN          False               False
# 1150793                     NaN          False               False
# 1150794                    18.0          False               False
# 1150821                     NaN          False               False
# 1150856                     NaN          False               False
# 1150903                     NaN          False               False
# 1150904                     2.0          False               False
# 1151026                     NaN          False               False
# 1151027                    15.0          False               False
# 1151085                     NaN          False               False

# %%
processed_sorted_df['sitio_subida'] = processed_sorted_df['sitio_subida'].str.replace("-", "")
processed_sorted_df['sitio_subida'] = processed_sorted_df['sitio_subida'].str.replace(" ", "")

processed_sorted_df['servicio_subida'] =  processed_sorted_df['servicio_subida'].str.replace('T','')
processed_sorted_df['servicio_subida'] =  processed_sorted_df['servicio_subida'].str.split(' ').str[0]
 
print('The number of rows in the original etapas database is: ' + str(len(processed_sorted_df.index)) + ' rows.' )
#Filtering special cases.
filtered_processed_sorted_df = processed_sorted_df[(processed_sorted_df['diferencia_tiempo_secs']<=20)|(processed_sorted_df['diferencia_tiempo_secs'].isnull())]
print('The number of rows in the filtered (by special cases) etapas database is: '  + str(len(filtered_processed_sorted_df.index)) + ' rows.' )

[evasion_by_date, patentes_by_date, servicios_by_date] = MatchingUsers.simplifyingEvasion(common_dates_evasion,date) #Getting patentes and servicios surveyed in date...
    
clean_sorted_df = filtered_processed_sorted_df[(filtered_processed_sorted_df['sitio_subida'].isin(patentes_by_date))&(filtered_processed_sorted_df['servicio_subida'].isin(servicios_by_date))] #Filtering...
clean_sorted_df = clean_sorted_df.reset_index(drop=True)
print('The number of rows in the clean_sorted_df is: '  + str(len(clean_sorted_df.index)) + ' rows.' )

clean_sorted_df_1 = MatchingUsers.appendingIdExpedicion(clean_sorted_df,'15 minutes') #Appending (ad-hoc) id expedicion.
# Out:
# The number of rows in the original etapas database is: 2326044 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2267188 rows.
# The number of rows in the clean_sorted_df is: 11705 rows.

# %%
patente = 'CJRX76'

# %%
clean_sorted_df[(clean_sorted_df['sitio_subida']==patente)&(clean_sorted_df['par_subida']==paradero)]
# Out:
#         index          id  nviaje tipo_transporte            t_subida  \
# 5502  1380146  2501161870       1             BUS 2017-07-19 07:16:08
# 5567   688740   474307586       1             BUS 2017-07-19 09:32:16
# 5629     9244    24186706       1             BUS 2017-07-19 11:22:12
# 5649  1383987  2503728606       1             BUS 2017-07-19 12:16:10
# 5650  1487788  2687844446       1             BUS 2017-07-19 12:16:28
# 5672  1006350  1369948350       2             BUS 2017-07-19 13:15:09
# 5704    73289    35127314       1             BUS 2017-07-19 14:15:24
# 5743  1631751  2802915950       3             BUS 2017-07-19 16:10:01
# 5744  1005065  1363693412       1             BUS 2017-07-19 16:10:03
# 5851  2106611  3656517163       2             BUS 2017-07-19 19:29:59
# 5852   887036   931720299       3             BUS 2017-07-19 19:30:14
# 5900   873050   930184523       1             BUS 2017-07-19 22:57:23
#
#      servicio_subida    par_subida sitio_subida fecha_instalacion  \
# 5502             457  L-33-84-5-OP       CJRX76               NaT
# 5567             457  L-33-84-5-OP       CJRX76               NaT
# 5629             457  L-33-84-5-OP       CJRX76               NaT
# 5649             457  L-33-84-5-OP       CJRX76               NaT
# 5650             457  L-33-84-5-OP       CJRX76               NaT
# 5672             457  L-33-84-5-OP       CJRX76               NaT
# 5704             457  L-33-84-5-OP       CJRX76               NaT
# 5743             457  L-33-84-5-OP       CJRX76               NaT
# 5744             457  L-33-84-5-OP       CJRX76               NaT
# 5851             457  L-33-84-5-OP       CJRX76               NaT
# 5852             457  L-33-84-5-OP       CJRX76               NaT
# 5900             457  L-33-84-5-OP       CJRX76               NaT
#
#       mismo_paradero  misma_patente  mismo_servicio diferencia_tiempo  \
# 5502           False           True            True               NaT
# 5567           False           True           False               NaT
# 5629           False           True           False               NaT
# 5649           False           True           False               NaT
# 5650            True           True            True          00:00:18
# 5672           False           True            True               NaT
# 5704           False           True           False               NaT
# 5743           False           True           False               NaT
# 5744            True           True            True          00:00:02
# 5851           False           True           False               NaT
# 5852            True           True            True          00:00:15
# 5900           False           True            True               NaT
#
#       diferencia_tiempo_secs  si_torniquete  si_2017_torniquete idExpedicion
# 5502                     NaN          False               False            7
# 5567                     NaN          False               False           10
# 5629                     NaN          False               False           11
# 5649                     NaN          False               False           12
# 5650                    18.0          False               False           12
# 5672                     NaN          False               False           12
# 5704                     NaN          False               False           13
# 5743                     NaN          False               False           15
# 5744                     2.0          False               False           15
# 5851                     NaN          False               False           18
# 5852                    15.0          False               False           18
# 5900                     NaN          False               False           23

# %%
clean_sorted_df.loc[5645:5672]
# Out:
#         index          id  nviaje tipo_transporte            t_subida  \
# 5645   858113   918672379       3             BUS 2017-07-19 11:48:48
# 5646  1953102  3541942539       1             BUS 2017-07-19 11:48:55
# 5647  2118986  3727357672       1             BUS 2017-07-19 12:00:54
# 5648  1819090  3257056216       1             BUS 2017-07-19 12:00:57
# 5649  1383987  2503728606       1             BUS 2017-07-19 12:16:10
# 5650  1487788  2687844446       1             BUS 2017-07-19 12:16:28
# 5651   644287   433380418       1             BUS 2017-07-19 12:20:29
# 5652  1750887  3168516478       1             BUS 2017-07-19 12:23:52
# 5653     5023    23461394       1             BUS 2017-07-19 12:28:19
# 5654   559493   423689090       1             BUS 2017-07-19 12:28:20
# 5655   121195    41472978       1             BUS 2017-07-19 12:28:22
# 5656   977214  1291130398       2             BUS 2017-07-19 12:29:31
# 5657    61677    33771810       1             BUS 2017-07-19 12:30:05
# 5658  2143077  3856991419       1             BUS 2017-07-19 12:33:13
# 5659  1190359  2036577587       1             BUS 2017-07-19 12:33:15
# 5660   165323    50880290       1             BUS 2017-07-19 12:37:11
# 5661   627700   430593282       1             BUS 2017-07-19 12:37:14
# 5662  1762328  3169974350       1             BUS 2017-07-19 12:43:42
# 5663  1733200  3138817598       1             BUS 2017-07-19 12:46:22
# 5664    10203    24352546       1             BUS 2017-07-19 12:46:27
# 5665  1010733  1401794536       1             BUS 2017-07-19 12:46:44
# 5666   935749  1086784980       1             BUS 2017-07-19 12:46:49
# 5667  1406983  2510441326       1             BUS 2017-07-19 12:46:52
# 5668   926761   982259002       1             BUS 2017-07-19 12:46:55
# 5669  1825589  3263307284       1             BUS 2017-07-19 12:48:08
# 5670  1431707  2519920814       1             BUS 2017-07-19 13:01:49
# 5671  1297953  2371515870       1             BUS 2017-07-19 13:13:37
# 5672  1006350  1369948350       2             BUS 2017-07-19 13:15:09
#
#      servicio_subida     par_subida sitio_subida fecha_instalacion  \
# 5645             457   L-32-28-2-OP       CJRX76               NaT
# 5646             457   L-32-28-2-OP       CJRX76               NaT
# 5647             457   L-32-25-5-SN       CJRX76               NaT
# 5648             457   L-32-25-5-SN       CJRX76               NaT
# 5649             457   L-33-84-5-OP       CJRX76               NaT
# 5650             457   L-33-84-5-OP       CJRX76               NaT
# 5651             457  L-32-31-25-SN       CJRX76               NaT
# 5652             457   L-32-7-50-SN       CJRX76               NaT
# 5653             457  L-32-23-55-OP       CJRX76               NaT
# 5654             457  L-32-23-55-OP       CJRX76               NaT
# 5655             457  L-32-23-55-OP       CJRX76               NaT
# 5656             457  L-32-23-45-OP       CJRX76               NaT
# 5657             457  L-32-23-35-OP       CJRX76               NaT
# 5658             457  L-32-33-50-NS       CJRX76               NaT
# 5659             457  L-32-33-50-NS       CJRX76               NaT
# 5660             457   L-32-28-7-OP       CJRX76               NaT
# 5661             457   L-32-28-7-OP       CJRX76               NaT
# 5662             457   L-32-28-2-OP       CJRX76               NaT
# 5663             457   L-32-28-2-OP       CJRX76               NaT
# 5664             457   L-32-28-2-OP       CJRX76               NaT
# 5665             457   L-32-28-2-OP       CJRX76               NaT
# 5666             457   L-32-28-2-OP       CJRX76               NaT
# 5667             457   L-32-28-2-OP       CJRX76               NaT
# 5668             457   L-32-28-2-OP       CJRX76               NaT
# 5669             457   L-32-28-2-OP       CJRX76               NaT
# 5670             457   L-32-25-5-SN       CJRX76               NaT
# 5671             457   L-33-84-3-OP       CJRX76               NaT
# 5672             457   L-33-84-5-OP       CJRX76               NaT
#
#       mismo_paradero  misma_patente  mismo_servicio diferencia_tiempo  \
# 5645            True           True            True          00:00:17
# 5646            True           True            True          00:00:07
# 5647           False           True            True               NaT
# 5648            True           True            True          00:00:03
# 5649           False           True           False               NaT
# 5650            True           True            True          00:00:18
# 5651           False           True            True               NaT
# 5652           False           True            True               NaT
# 5653           False           True            True               NaT
# 5654            True           True            True          00:00:01
# 5655            True           True            True          00:00:02
# 5656           False           True            True               NaT
# 5657           False           True            True               NaT
# 5658           False           True            True               NaT
# 5659            True           True            True          00:00:02
# 5660           False           True            True               NaT
# 5661            True           True            True          00:00:03
# 5662           False           True           False               NaT
# 5663            True           True            True          00:00:03
# 5664            True           True            True          00:00:05
# 5665            True           True            True          00:00:17
# 5666            True           True            True          00:00:05
# 5667            True           True            True          00:00:03
# 5668            True           True            True          00:00:03
# 5669            True           True            True          00:00:13
# 5670           False           True            True               NaT
# 5671           False           True           False               NaT
# 5672           False           True            True               NaT
#
#       diferencia_tiempo_secs  si_torniquete  si_2017_torniquete idExpedicion
# 5645                    17.0          False               False           11
# 5646                     7.0          False               False           11
# 5647                     NaN          False               False           11
# 5648                     3.0          False               False           11
# 5649                     NaN          False               False           12
# 5650                    18.0          False               False           12
# 5651                     NaN          False               False           12
# 5652                     NaN          False               False           12
# 5653                     NaN          False               False           12
# 5654                     1.0          False               False           12
# 5655                     2.0          False               False           12
# 5656                     NaN          False               False           12
# 5657                     NaN          False               False           12
# 5658                     NaN          False               False           12
# 5659                     2.0          False               False           12
# 5660                     NaN          False               False           12
# 5661                     3.0          False               False           12
# 5662                     NaN          False               False           12
# 5663                     3.0          False               False           12
# 5664                     5.0          False               False           12
# 5665                    17.0          False               False           12
# 5666                     5.0          False               False           12
# 5667                     3.0          False               False           12
# 5668                     3.0          False               False           12
# 5669                    13.0          False               False           12
# 5670                     NaN          False               False           12
# 5671                     NaN          False               False           12
# 5672                     NaN          False               False           12

# %%
clean_sorted_df_1[(clean_sorted_df_1['sitio_subida']==patente)&(clean_sorted_df_1['par_subida']==paradero)]
# Out:
#         index          id  nviaje tipo_transporte            t_subida  \
# 5502  1380146  2501161870       1             BUS 2017-07-19 07:16:08
# 5567   688740   474307586       1             BUS 2017-07-19 09:32:16
# 5629     9244    24186706       1             BUS 2017-07-19 11:22:12
# 5649  1383987  2503728606       1             BUS 2017-07-19 12:16:10
# 5650  1487788  2687844446       1             BUS 2017-07-19 12:16:28
# 5672  1006350  1369948350       2             BUS 2017-07-19 13:15:09
# 5704    73289    35127314       1             BUS 2017-07-19 14:15:24
# 5743  1631751  2802915950       3             BUS 2017-07-19 16:10:01
# 5744  1005065  1363693412       1             BUS 2017-07-19 16:10:03
# 5851  2106611  3656517163       2             BUS 2017-07-19 19:29:59
# 5852   887036   931720299       3             BUS 2017-07-19 19:30:14
# 5900   873050   930184523       1             BUS 2017-07-19 22:57:23
#
#      servicio_subida    par_subida sitio_subida fecha_instalacion  \
# 5502             457  L-33-84-5-OP       CJRX76               NaT
# 5567             457  L-33-84-5-OP       CJRX76               NaT
# 5629             457  L-33-84-5-OP       CJRX76               NaT
# 5649             457  L-33-84-5-OP       CJRX76               NaT
# 5650             457  L-33-84-5-OP       CJRX76               NaT
# 5672             457  L-33-84-5-OP       CJRX76               NaT
# 5704             457  L-33-84-5-OP       CJRX76               NaT
# 5743             457  L-33-84-5-OP       CJRX76               NaT
# 5744             457  L-33-84-5-OP       CJRX76               NaT
# 5851             457  L-33-84-5-OP       CJRX76               NaT
# 5852             457  L-33-84-5-OP       CJRX76               NaT
# 5900             457  L-33-84-5-OP       CJRX76               NaT
#
#       mismo_paradero  misma_patente  mismo_servicio diferencia_tiempo  \
# 5502           False           True            True               NaT
# 5567           False           True           False               NaT
# 5629           False           True           False               NaT
# 5649           False           True           False               NaT
# 5650            True           True            True          00:00:18
# 5672           False           True            True               NaT
# 5704           False           True           False               NaT
# 5743           False           True           False               NaT
# 5744            True           True            True          00:00:02
# 5851           False           True           False               NaT
# 5852            True           True            True          00:00:15
# 5900           False           True            True               NaT
#
#       diferencia_tiempo_secs  si_torniquete  si_2017_torniquete idExpedicion
# 5502                     NaN          False               False            7
# 5567                     NaN          False               False           10
# 5629                     NaN          False               False           11
# 5649                     NaN          False               False           12
# 5650                    18.0          False               False           12
# 5672                     NaN          False               False           12
# 5704                     NaN          False               False           13
# 5743                     NaN          False               False           15
# 5744                     2.0          False               False           15
# 5851                     NaN          False               False           18
# 5852                    15.0          False               False           18
# 5900                     NaN          False               False           23

# %%
from Utils import PrintLinesUtils

# %%
PrintLinesUtils.readAndPrintLines('perfiles','10','2017-03-01')
# Out:
# ServicioSentido|Patente|Paradero|NombreParada|Hini|Hfin|Cumplimiento|Correlativo|idExpedicion|DistEnRuta|#Subidas|#SubidasLejanas|Subidastotal|SubidasExpandidas|#Bajadas|#BajadasLejanas|Bajadastotal|BajadasExpandidas|Carga|Capacidad|TiempoGPSInterpolado|TiempoPrimeraTrx|TiempoGPSMasCercano|Tiempo|nSubidasTmp|ParaderoUsuario|PeriodoTSExpedicion|PeriodoTSParada|TipoDia|ZP|DeltaTrxs
#
# T118 00I|ZB-6854|T-13-369-PO-5|René Olivares esq. / Los Olivares|2017-03-01 01:32:45|2017-03-01 01:42:14|NC|1|0|120|0|0|0|0|0|0|0|0|0|91|-|-|01:32:15|2017-03-01 01:32:15|0|PI528|02 - NOCTURNO|02 - NOCTURNO|LABORAL|0|0
#
# T118 00I|ZB-6854|L-13-69-5-PO|René Olivares esq. / Avenida 4 Poniente|2017-03-01 01:32:45|2017-03-01 01:42:14|NC|2|0|392|0|0|0|0|0|0|0|0|0|91|01:32:23|-|01:32:15|2017-03-01 01:32:23|0|PI529|02 - NOCTURNO|02 - NOCTURNO|LABORAL|0|0
#
# T118 00I|ZB-6854|L-13-3-42-SN|Avenida 4 Poniente esq. / Pdte. J.M Balmaceda|2017-03-01 01:32:45|2017-03-01 01:42:14|NC|3|0|595|0|0|0|0|0|0|0|0|0|91|01:35:20|-|01:33:15|2017-03-01 01:35:20|0|PI1350|02 - NOCTURNO|02 - NOCTURNO|LABORAL|0|0
#
# T118 00I|ZB-6854|T-13-91-OP-5|Avenida 4 Poniente esq. / Av. González Videla|2017-03-01 01:32:45|2017-03-01 01:42:14|NC|4|0|888|0|0|0|0|0|0|0|0|0|91|01:35:30|-|01:35:45|2017-03-01 01:35:30|0|PI89|02 - NOCTURNO|02 - NOCTURNO|LABORAL|0|0
#
# T118 00I|ZB-6854|T-13-105-SN-5|Pdte. G. Videla esq. / Cerro Blanco|2017-03-01 01:32:45|2017-03-01 01:42:14|NC|5|0|1251|0|0|0|0|0|0|0|0|0|91|01:35:41|-|01:35:45|2017-03-01 01:35:41|0|PI90|02 - NOCTURNO|02 - NOCTURNO|LABORAL|0|0
#
# T118 00I|ZB-6854|T-13-105-SN-10|Pdte. G. Videla esq. / Chipana|2017-03-01 01:32:45|2017-03-01 01:42:14|NC|6|0|1505|0|0|0|0|0|0|0|0|0|91|01:35:52|-|01:35:45|2017-03-01 01:35:52|0|PI91|02 - NOCTURNO|02 - NOCTURNO|LABORAL|0|0
#
# T118 00I|ZB-6854|T-13-93-PO-5|A. Silva Carvallo esq. / Pdte. J.M Balmaceda|2017-03-01 01:32:45|2017-03-01 01:42:14|NC|7|0|1858|0|0|0|0|0|0|0|0|0|91|01:36:10|-|01:36:15|2017-03-01 01:36:10|0|PI92|02 - NOCTURNO|02 - NOCTURNO|LABORAL|0|0
#
# T118 00I|ZB-6854|T-13-93-PO-10|A. Silva Carvallo esq. / Avenida 3 Poniente|2017-03-01 01:32:45|2017-03-01 01:42:14|NC|8|0|2276|0|0|0|0|0|0|0|0|0|91|01:37:14|-|01:37:15|2017-03-01 01:37:14|0|PI93|02 - NOCTURNO|02 - NOCTURNO|LABORAL|0|0
#
# T118 00I|ZB-6854|T-13-93-PO-15|A. Silva Carvallo esq. / Tito Mundt|2017-03-01 01:32:45|2017-03-01 01:42:14|NC|9|0|2534|0|0|0|0|0|0|0|0|0|91|01:39:09|-|01:39:15|2017-03-01 01:39:09|0|PI94|02 - NOCTURNO|02 - NOCTURNO|LABORAL|0|0

# %% [markdown]
# ### Re-doing for timeDelta = 30 seconds

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# %matplotlib inline
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from importlib import reload
import datetime as dt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from Utils import TransantiagoConstants
import EvasionBuilder

# %%
processed_evasion = EvasionBuilder.runCompleteProcess()
# Out:
# Original number of rows in complete evasion database is: 97373
# Number of duplicated rows in complete evasion database is: 6192
# Number of collapsed-duplicated rows in complete evasion database is: 3090
# Number of rows in complete evasion database without duplicated rows at all is: 91181
# Final number of rows in complete evasion database with collapsed duplicated rows is: 94271
# C:\Users\leoca_000\Anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\leoca_000\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# The only non-matched user_code services are:
# D06

# %% [markdown]
# * Processing complete evasion-ddbb

# %%
evasion_paradero = processed_evasion[processed_evasion['TP']=='P']
evasion_paradero_first = evasion_paradero[evasion_paradero['N_PUERTA']==1]

# %%
print('Number of rows in complete evasion database is: ' + str(len(processed_evasion.index)))
print('Number of rows in evasion in paradero database is: ' + str(len(evasion_paradero.index)))
print('Number of rows in evasion in paradero by first door database is: ' + str(len(evasion_paradero_first.index)))
# Out:
# Number of rows in complete evasion database is: 94271
# Number of rows in evasion in paradero database is: 92604
# Number of rows in evasion in paradero by first door database is: 33120

# %% [markdown]
# * Filtering dates not in common dates. DataFrame "common_dates_evasion" will be the final evasion DataFrame

# %%
common_dates = TransantiagoConstants.common_dates
common_dates_timestamp = [pd.to_datetime(x) for x in common_dates]
common_dates_evasion = evasion_paradero_first[evasion_paradero_first['FECHA'].isin(common_dates_timestamp)]

print('Number of rows in complete evasion database filtered by common_dates is: ' + str(len(common_dates_evasion.index))) #Remember to store the number.
# Out:
# Number of rows in complete evasion database filtered by common_dates is: 14632

# %% [markdown]
# * Building Etapas DataBase via <strong>DailyEtapasBuilder</strong> and matching users via <strong>MatchingUsers</strong>

# %%
#common_dates = ['2017-04-11']

# %%
import DailyEtapasBuilder

# %%
import MatchingUsers

# %%
summary_evasion_vs_mean = pd.DataFrame()

for date in common_dates:    
    etapas_builder = DailyEtapasBuilder.RunSilentlyDailyEtapasBuilderClass(date)
    etapas_builder.loadSimplifiedEtapas()
    etapas_builder.mergeTurnstileData()
    etapas_builder.cleanDataFrame()
    etapas_builder.sortDataFrame()
    etapas_builder.postProcessingSortedDataFrame()
    processed_sorted_df = etapas_builder.etapas_df    
    processed_sorted_df['sitio_subida'] = processed_sorted_df['sitio_subida'].str.replace("-", "")
    processed_sorted_df['sitio_subida'] = processed_sorted_df['sitio_subida'].str.replace(" ", "")
    
    processed_sorted_df['servicio_subida'] =  processed_sorted_df['servicio_subida'].str.replace('T','')
    processed_sorted_df['servicio_subida'] =  processed_sorted_df['servicio_subida'].str.split(' ').str[0]
    
    print('The number of rows in the original etapas database is: ' + str(len(processed_sorted_df.index)) + ' rows.' )
    #Filtering special cases.
#    filtered_processed_sorted_df = processed_sorted_df[(processed_sorted_df['diferencia_tiempo_secs']<=20)|(processed_sorted_df['diferencia_tiempo_secs'].isnull())]
    filtered_processed_sorted_df = processed_sorted_df
    print('The number of rows in the filtered (by special cases) etapas database is: '  + str(len(filtered_processed_sorted_df.index)) + ' rows.' )
    
    [evasion_by_date, patentes_by_date, servicios_by_date] = MatchingUsers.simplifyingEvasion(common_dates_evasion,date) #Getting patentes and servicios surveyed in date...
    
    clean_sorted_df = filtered_processed_sorted_df[(filtered_processed_sorted_df['sitio_subida'].isin(patentes_by_date))&(filtered_processed_sorted_df['servicio_subida'].isin(servicios_by_date))] #Filtering...
    clean_sorted_df = clean_sorted_df.reset_index(drop=True)
    print('The number of rows in the clean_sorted_df is: '  + str(len(clean_sorted_df.index)) + ' rows.' )

    clean_sorted_df_1 = MatchingUsers.appendingIdExpedicion(clean_sorted_df,'30 seconds') #Appending (ad-hoc) id expedicion.
    grouped_clean_sorted_df_1 = MatchingUsers.groupByEtapasDatabase(clean_sorted_df_1) #Grouping by 'sitio_subida','servicio_subida','idExpedicion','par_subida'
    grouped_clean_sorted_df_2 = MatchingUsers.appendingStartEndCuts(grouped_clean_sorted_df_1) #Computing start and end cuts.
    grouped_clean_sorted_df_3 = MatchingUsers.slicingEvasionDatabase(grouped_clean_sorted_df_2,evasion_by_date) #This is the final ddbb with full info.
    grouped_clean_sorted_df_4 = MatchingUsers.reMergeTurnstileData(grouped_clean_sorted_df_3)
    summary_evasion_vs_mean = pd.concat([summary_evasion_vs_mean,grouped_clean_sorted_df_4])
# Out:
# Not found in turnstile database: 1795630
# The number of rows in the original etapas database is: 2535246 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2535246 rows.
# The number of rows in the clean_sorted_df is: 2553 rows.
# Not found in turnstile database: 1832615
# The number of rows in the original etapas database is: 2591725 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2591725 rows.
# The number of rows in the clean_sorted_df is: 2921 rows.
# Not found in turnstile database: 1842842
# The number of rows in the original etapas database is: 2612985 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2612985 rows.
# The number of rows in the clean_sorted_df is: 9467 rows.
# Not found in turnstile database: 1821215
# The number of rows in the original etapas database is: 2589603 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2589603 rows.
# The number of rows in the clean_sorted_df is: 4807 rows.
# Not found in turnstile database: 1829611
# The number of rows in the original etapas database is: 2598131 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2598131 rows.
# The number of rows in the clean_sorted_df is: 11937 rows.
# Not found in turnstile database: 1889530
# The number of rows in the original etapas database is: 2678999 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2678999 rows.
# The number of rows in the clean_sorted_df is: 7093 rows.
# Not found in turnstile database: 1869904
# The number of rows in the original etapas database is: 2663162 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2663162 rows.
# The number of rows in the clean_sorted_df is: 12941 rows.
# Not found in turnstile database: 517700
# The number of rows in the original etapas database is: 803771 rows.
# The number of rows in the filtered (by special cases) etapas database is: 803771 rows.
# The number of rows in the clean_sorted_df is: 2870 rows.
# Not found in turnstile database: 1764405
# The number of rows in the original etapas database is: 2525338 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2525338 rows.
# The number of rows in the clean_sorted_df is: 14310 rows.
# Not found in turnstile database: 1680579
# The number of rows in the original etapas database is: 2390427 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2390427 rows.
# The number of rows in the clean_sorted_df is: 4937 rows.
# Not found in turnstile database: 1560500
# The number of rows in the original etapas database is: 2222618 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2222618 rows.
# The number of rows in the clean_sorted_df is: 4008 rows.
# Not found in turnstile database: 1598721
# The number of rows in the original etapas database is: 2272834 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2272834 rows.
# The number of rows in the clean_sorted_df is: 12248 rows.
# Not found in turnstile database: 1637796
# The number of rows in the original etapas database is: 2326044 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2326044 rows.
# The number of rows in the clean_sorted_df is: 12414 rows.
# Not found in turnstile database: 1876347
# The number of rows in the original etapas database is: 2679443 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2679443 rows.
# The number of rows in the clean_sorted_df is: 6782 rows.
# Not found in turnstile database: 1867643
# The number of rows in the original etapas database is: 2653409 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2653409 rows.
# The number of rows in the clean_sorted_df is: 6045 rows.
# Not found in turnstile database: 1873694
# The number of rows in the original etapas database is: 2668607 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2668607 rows.
# The number of rows in the clean_sorted_df is: 11805 rows.
# Not found in turnstile database: 1877006
# The number of rows in the original etapas database is: 2673767 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2673767 rows.
# The number of rows in the clean_sorted_df is: 11314 rows.
# Not found in turnstile database: 1842523
# The number of rows in the original etapas database is: 2636529 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2636529 rows.
# The number of rows in the clean_sorted_df is: 4112 rows.

# %%
print('The number of rows in the summary_evasion_vs_mean: '  + str(len(summary_evasion_vs_mean.index)) + ' rows.' )
# Out:
# The number of rows in the summary_evasion_vs_mean: 56393 rows.

# %%
summary_evasion_vs_mean.loc[:,'EVASION_RATE'] = summary_evasion_vs_mean.loc[:,'TOTAL_NO_VALIDAN']/summary_evasion_vs_mean.loc[:,'TOTAL_INGRESAN']

not_null_mean_summary = summary_evasion_vs_mean[summary_evasion_vs_mean['diferencia_tiempo_secs_mean'].notnull()]
not_null_mean_count_summary = not_null_mean_summary[not_null_mean_summary['EVASION_COUNT']>0]
not_null_mean_count_summary_no_turns = not_null_mean_count_summary[(not_null_mean_count_summary['SI_TORNIQUETE']==False)|((not_null_mean_count_summary['SI_TORNIQUETE']==True) & (not_null_mean_count_summary['t_subida_max']<=not_null_mean_count_summary['fecha_instalacion']))]

# %%
print('The number of rows in the not_null_mean_summary dataframe is: ' + str(len(not_null_mean_summary.index)) + ' rows.')
print('The number of rows in the not_null_mean_count_summary dataframe is: ' + str(len(not_null_mean_count_summary.index)) + ' rows.')
print('The number of rows in the not_null_mean_count_summary_no_turns dataframe is: ' + str(len(not_null_mean_count_summary_no_turns.index)) + ' rows.')
# Out:
# The number of rows in the not_null_mean_summary dataframe is: 29345 rows.
# The number of rows in the not_null_mean_count_summary dataframe is: 2820 rows.
# The number of rows in the not_null_mean_count_summary_no_turns dataframe is: 2139 rows.

# %%
fig_2, ax_2 = plt.subplots()

ax_2.scatter(not_null_mean_count_summary_no_turns['diferencia_tiempo_secs_mean'],not_null_mean_count_summary_no_turns['EVASION_RATE'])
ax_2.set_title('Evasion vs. Mean Time - No Turns, By Bus, Service, Stop, 30Secs')
ax_2.set_xlabel('Mean Time Interval [s]')
ax_2.set_ylabel('Evasion Rate [%]')

plt.savefig('C:/Users/leoca_000/Desktop/Evasion/03_report/02_Figs/9_30Secs_EvasionVsMeanTimeByBusByServiceByStop.pdf')

# %% [markdown]
# ### Analyzing - 30Secs (but via different methodology)

# %%
not_null_mean_count_summary_no_turns = not_null_mean_count_summary_no_turns.reset_index(drop=True)

# %% [markdown]
# * Obs. with diferencia_tiempo_secs_mean>=200

# %%
not_null_mean_count_summary_no_turns[not_null_mean_count_summary_no_turns['diferencia_tiempo_secs_mean']>=200]
# Out:
#      sitio_subida servicio_subida  idExpedicion     par_subida  \
# 517        CJRZ38             456           737   L-32-28-2-OP
# 896        ZN4200             102            94  T-34-269-SN-5
# 1403       BJFS32             358           123   L-34-87-5-OP
# 1653       BJFT77             355           440  T-26-12-PO-22
#
#             t_subida_min        t_subida_max  t_subida_count  \
# 517  2017-04-11 16:45:59 2017-04-11 16:45:59               1
# 896  2017-06-14 18:44:57 2017-06-14 18:44:57               1
# 1403 2017-07-19 07:15:03 2017-07-19 07:15:03               1
# 1653 2017-08-09 09:45:28 2017-08-09 09:45:28               1
#
#       diferencia_tiempo_secs_mean            start_cut              end_cut  \
# 517                         204.0  2017-04-11 16:45:29  2017-04-11 16:46:29
# 896                         302.0  2017-06-14 18:44:27  2017-06-14 18:45:27
# 1403                        378.0  2017-07-19 07:14:33  2017-07-19 07:15:33
# 1653                        273.0  2017-08-09 09:44:58  2017-08-09 09:45:58
#
#       EVASION_COUNT  TOTAL_INGRESAN  TOTAL_NO_VALIDAN fecha_instalacion  \
# 517             1.0             5.0               0.0               NaT
# 896             1.0             2.0               0.0               NaT
# 1403            1.0             3.0               0.0               NaT
# 1653            1.0             5.0               0.0               NaT
#
#       SI_TORNIQUETE  SI_2017_TORNIQUETE  EVASION_RATE
# 517           False               False           0.0
# 896           False               False           0.0
# 1403          False               False           0.0
# 1653          False               False           0.0

# %%
date = '2017-07-19'
patente = 'BJFS-32'
paradero = 'L-34-87-5-OP'

# %%
etapas_builder = DailyEtapasBuilder.RunSilentlyDailyEtapasBuilderClass(date)
etapas_builder.loadSimplifiedEtapas()
etapas_builder.mergeTurnstileData()
etapas_builder.cleanDataFrame()
etapas_builder.sortDataFrame()
etapas_builder.postProcessingSortedDataFrame()
processed_sorted_df = etapas_builder.etapas_df
# Out:
# Not found in turnstile database: 1637796

# %%
processed_sorted_df['sitio_subida'] = processed_sorted_df['sitio_subida'].str.replace("-", "")
processed_sorted_df['sitio_subida'] = processed_sorted_df['sitio_subida'].str.replace(" ", "")

processed_sorted_df['servicio_subida'] =  processed_sorted_df['servicio_subida'].str.replace('T','')
processed_sorted_df['servicio_subida'] =  processed_sorted_df['servicio_subida'].str.split(' ').str[0]
 
print('The number of rows in the original etapas database is: ' + str(len(processed_sorted_df.index)) + ' rows.' )
#Filtering special cases.
#filtered_processed_sorted_df = processed_sorted_df[(processed_sorted_df['diferencia_tiempo_secs']<=20)|(processed_sorted_df['diferencia_tiempo_secs'].isnull())]
filtered_processed_sorted_df=processed_sorted_df
print('The number of rows in the filtered (by special cases) etapas database is: '  + str(len(filtered_processed_sorted_df.index)) + ' rows.' )

[evasion_by_date, patentes_by_date, servicios_by_date] = MatchingUsers.simplifyingEvasion(common_dates_evasion,date) #Getting patentes and servicios surveyed in date...
    
clean_sorted_df = filtered_processed_sorted_df[(filtered_processed_sorted_df['sitio_subida'].isin(patentes_by_date))&(filtered_processed_sorted_df['servicio_subida'].isin(servicios_by_date))] #Filtering...
clean_sorted_df = clean_sorted_df.reset_index(drop=True)
print('The number of rows in the clean_sorted_df is: '  + str(len(clean_sorted_df.index)) + ' rows.' )

clean_sorted_df_1 = MatchingUsers.appendingIdExpedicion(clean_sorted_df,'30 seconds') #Appending (ad-hoc) id expedicion.
# Out:
# The number of rows in the original etapas database is: 2326044 rows.
# The number of rows in the filtered (by special cases) etapas database is: 2326044 rows.
# The number of rows in the clean_sorted_df is: 12414 rows.

# %%
patente = 'BJFS32'

# %%
clean_sorted_df[(clean_sorted_df['sitio_subida']==patente)&(clean_sorted_df['idExpedicion']==123)]
# Out:
#         index          id  nviaje tipo_transporte            t_subida  \
# 1133  1759395  3169614158       1             BUS 2017-07-19 07:15:03
#
#      servicio_subida    par_subida sitio_subida fecha_instalacion  \
# 1133             358  L-34-87-5-OP       BJFS32               NaT
#
#       mismo_paradero  misma_patente  mismo_servicio diferencia_tiempo  \
# 1133            True           True            True          00:06:18
#
#       diferencia_tiempo_secs  si_torniquete  si_2017_torniquete idExpedicion
# 1133                   378.0          False               False          123
