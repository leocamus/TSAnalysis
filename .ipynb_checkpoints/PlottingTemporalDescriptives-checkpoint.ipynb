# %% [markdown]
# ### Notebook to plot all the necessary descriptives in time

# %%
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt
import time
from importlib import reload
# Out:
# <style>.container { width:80% !important; }</style>

# %%
#summary_descriptives = pd.read_csv('C:/Users/Tesista/Desktop/Evasion/01_analisis/03_datos/05_SUMMARY/DescriptivesSummary.csv', sep=';', encoding = 'latin-1')
summary_descriptives = pd.read_csv('C:/Users/leoca_000/Desktop/Evasion/01_analisis/03_datos/05_SUMMARY/DescriptivesSummary.csv', sep=';', encoding = 'latin-1')

# %%
dates = summary_descriptives['date']
dates = [dt.datetime.strptime(x, "%Y-%m-%d").date() for x in dates]

# %%
colors = [(85,98,112),(78,205,196),(199,244,100),(255,107,107),(196,77,88)]
for i in range(len(colors)):
    r, g, b = colors[i]  
    colors[i] = (r / 255., g / 255., b / 255.)

# %%
turnstile_means = summary_descriptives['turnstile_means']
no_turnstile_means = summary_descriptives['no_turnstile_means']

# %%
summary_descriptives['mean_difference'] =  [x - y for x, y in zip(turnstile_means, no_turnstile_means)]

# %% [markdown]
# * All dates

# %%
outlier_1 = dt.date(2017,4,10)
outlier_2 = dt.date(2017,4,17)

new_dates = [x for x in dates if ((x!=outlier_1)&(x!=outlier_2))]                                  
new_turnstile_means = [x for x in turnstile_means if x<15]
new_no_turnstile_means = [x for x in no_turnstile_means if x<15]

fig, ax_1 = plt.subplots()

ax_1.plot(new_dates,new_turnstile_means, color = colors [3], label='2017 turnstiles')
ax_1.plot(new_dates,new_no_turnstile_means, color = colors [0], label='no turnstiles')

fig.autofmt_xdate()
ax_1.legend()

ax_1.set_title('Mean of time intervals evolution')
ax_1.set_ylabel('Mean of time intervals [s]')

#plt.savefig('C:/Users/Tesista/Desktop/Evasion/03_report/02_Figs/7_meansEvolutionInTime.pdf')

# %% [markdown]
# * Plotting difference of means

# %%
hist_fig, ax = plt.subplots()

plot1 = ax.hist(turns_vals,normed=True,bins=bins,color=colors[3], alpha=0.8, label='with 2017 turnstiles')
plot2 = ax.hist(no_turns_vals,normed=True,bins=bins,color=colors[0], alpha = 0.8, label='without turnstiles')


ax.set_title('Time-interval between transactions (97th)')
ax.set_xlabel('time-interval[s]')
ax.set_ylabel('Relative Frequency')
ax.legend()
plt.savefig('C:/Users/Tesista/Desktop/Evasion/03_report/02_Figs/2_daily2017-07-19.pdf')

# %% [markdown]
# * Omitting weekends

# %%
weekend = set([5, 6])

week_dates = []
week_turnstile_means = []
week_no_turnstile_means = []

for x, y, z in zip(dates, turnstile_means, no_turnstile_means):
    if (x.weekday() not in weekend):
        week_dates.append(x)
        week_turnstile_means.append(y)
        week_no_turnstile_means.append(z)

# %%
outlier_1 = dt.date(2017,4,10)
outlier_2 = dt.date(2017,4,17)

new_week_dates = [x for x in week_dates if ((x!=outlier_1)&(x!=outlier_2))]                                  
new_week_turnstile_means = [x for x in week_turnstile_means if x<15]
new_week_no_turnstile_means = [x for x in week_no_turnstile_means if x<15]

fig, ax_1 = plt.subplots()

ax_1.plot(new_week_dates,new_week_turnstile_means, color = colors [3], label='2017 turnstiles')
ax_1.plot(new_week_dates,new_week_no_turnstile_means, color = colors [0], label='no turnstiles')

fig.autofmt_xdate()
ax_1.legend()

ax_1.set_title('Mean of time intervals evolution')
ax_1.set_ylabel('Mean of time intervals [s]')

#plt.savefig('C:/Users/Tesista/Desktop/Evasion/03_report/02_Figs/7_meansEvolutionInTime.pdf')

# %% [markdown]
# * Omitting other special dates (holidays)

# %%
viernes_santo = dt.date(2017,4,14) #Friday
censo_abreviado = dt.date(2017,4,19) #Wednesday
dia_trabajo = dt.date(2017,5,1) #Monday
san_pedro = dt.date(2017,6,26) #Monday
asuncion_virgen = dt.date(2017,8,15) #Tuesday
special_dates = {viernes_santo,censo_abreviado,dia_trabajo,san_pedro,asuncion_virgen}

# %%
working_days = []
working_turnstile_means = []
working_no_turnstile_means = []

for x, y, z in zip(week_dates, week_turnstile_means, week_no_turnstile_means):
    if (x not in special_dates):
        working_days.append(x)
        working_turnstile_means.append(y)
        working_no_turnstile_means.append(z)

# %%
outlier_1 = dt.date(2017,4,10)
outlier_2 = dt.date(2017,4,17)

new_working_days = [x for x in working_days if ((x!=outlier_1)&(x!=outlier_2))]                                  
new_working_turnstile_means = [x for x in working_turnstile_means if x<15]
new_working_no_turnstile_means = [x for x in working_no_turnstile_means if x<15]

fig, ax_1 = plt.subplots()

ax_1.plot(new_working_days,new_working_turnstile_means, color = colors [3], label='2017 turnstiles')
ax_1.plot(new_working_days,new_working_no_turnstile_means, color = colors [0], label='no turnstiles')

fig.autofmt_xdate()
ax_1.legend()

ax_1.set_title('Mean of time intervals evolution')
ax_1.set_ylabel('Mean of time intervals [s]')

plt.savefig('C:/Users/leoca_000/Desktop/Evasion/03_report/02_Figs/7_WorkingMeansEvolutionInTime.pdf')

# %% [markdown]
# * There are more outliers to be filtered in trxs data. Consider to analyze them in detail

# %%
outlier_1 = dt.date(2017,4,10)
outlier_2 = dt.date(2017,4,17)

#new_dates = [x for x in week_dates if ((x!=outlier_1)&(x!=outlier_2))]
#new_turnstile_means = [x for x in turnstile_means if x<15]
#new_no_turnstile_means = [x for x in no_turnstile_means if x<15]

fig, ax_1 = plt.subplots()
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d/%m/%Y'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())

ax_1.plot(week_dates,week_raw_trx, color = colors[1], label='week - total-trx')


fig.autofmt_xdate()
#ax_1.legend()
ax_1.set_title('Total trx in time')

#plt.savefig('C:/Users/Tesista/Desktop/Evasion/03_report/02_Figs/6_meansEvolutionInTime.pdf')

# %%
clean_week_dates = []
clean_week_raw_trx =[]

for x, y in zip(week_dates, week_raw_trx):
    if (y>1500000):
        clean_week_dates.append(x)
        clean_week_raw_trx.append(y)

# %%
#outlier_1 = dt.date(2017,4,10)
#outlier_2 = dt.date(2017,4,17)

#new_dates = [x for x in week_dates if ((x!=outlier_1)&(x!=outlier_2))]
#new_turnstile_means = [x for x in turnstile_means if x<15]
#new_no_turnstile_means = [x for x in no_turnstile_means if x<15]

fig, ax_1 = plt.subplots()
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d/%m/%Y'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())

ax_1.plot(clean_week_dates,clean_week_raw_trx, color = colors[1], label='week - total-trx')


fig.autofmt_xdate()
#ax_1.legend()
ax_1.set_title('Total trx in time')

plt.savefig('C:/Users/leoca_000/Desktop/Evasion/03_report/02_Figs/7_tmpTrxEvolutionInTime.pdf')
