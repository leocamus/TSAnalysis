# %% [markdown]
# ### Analyzing all-dates descriptives

# %%
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt
import time

from importlib import reload
from Utils import TransantiagoConstants
from RunSilentlyDailyEtapasBuilder import RunSilentlyDailyEtapasBuilderClass
# Out:
# <style>.container { width:80% !important; }</style>

# %%
dates = TransantiagoConstants.currentSSHDates

# %% [markdown]
# * Not necessary again

# %%
#tic = time.clock()

#for date in dates:
#    etapas_builder = RunSilentlyDailyEtapasBuilderClass(date)
#    etapas_builder.runSimplifyEtapas()
#    del etapas_builder

#toc = time.clock()
#toc-tic

# %% [markdown]
# * Continuing with analyses.
# * <strike>Consider to refactor this block in order to get number of observations.</strike>
# * <strike>Consider to refactor this to get number of trx per database.</strike>
# * TODO: Consider to refactor this to get number of trx per database per operator -> this could be computationally expensive and not-so-easy, since it would be necessary to have some dictionary of operators and routes, and search between etapas and the dictionary.
# * <strike>Consider to refactor this to get number of already processed databases.</strike>
# * Methodology is not robust to potential databases particularities. <strong>Be aware of 2017-04-10 and 2017-04-17: outliers</strong>. Identification of issues with these particular databases should be done from outside
# * Identification of special dates should be done from outside.
# * Complete process (for all available dates) took about 35 minutes.

# %% [markdown]
# * Filtering to refactor

# %%
#dates = dates[:50]

# %% [markdown]
# * End filtering

# %%
#Raw number of trx per day: before cleaning
total_raw_trx = []

#Number of trx per day by turnstile condition: after cleaning but before filtering.
total_trx = []
total_turns_trx = []
total_no_turns_trx = []

#Descriptives: after cleaning and after filtering
turnstile_obs = []
turnstile_means = []
turnstile_medians = []
turnstile_stds = []
turnstile_maxs = []

no_turnstile_obs = []
no_turnstile_means = []
no_turnstile_medians = []
no_turnstile_stds = []
no_turnstile_maxs = []

quantile = 0.97
processed = 0

tic = time.clock()

for date in dates:
    etapas_builder = RunSilentlyDailyEtapasBuilderClass(date)
    [etapas_df, processed_sorted_df, filtered_df, filtered_turnstile_df, filtered_no_turnstile_df]=etapas_builder.runCompleteProcess()
    
    #Filling trx info:
    total_raw_trx.append(etapas_df.count()[0])
    total_trx.append(processed_sorted_df.count()[0])
    total_turns_trx.append(processed_sorted_df[processed_sorted_df.si_2017_torniquete==True].count()[0])
    total_no_turns_trx.append(processed_sorted_df[processed_sorted_df.si_torniquete==False].count()[0])
        
    #Filtering and following the original methodology:
    turnstile_q = filtered_turnstile_df.diferencia_tiempo.quantile(quantile)
    no_turnstile_q = filtered_no_turnstile_df.diferencia_tiempo.quantile(quantile)    
    
    filtered_turnstile_q_df = filtered_turnstile_df[filtered_turnstile_df.diferencia_tiempo<=turnstile_q]
    filtered_no_turnstile_q_df = filtered_no_turnstile_df[filtered_no_turnstile_df.diferencia_tiempo<=no_turnstile_q]
    
    turnstile_obs.append(filtered_turnstile_q_df.count()[0])
    turnstile_means.append(filtered_turnstile_q_df['diferencia_tiempo_secs'].mean())
    turnstile_stds.append(filtered_turnstile_q_df['diferencia_tiempo_secs'].std())
    turnstile_medians.append(filtered_turnstile_q_df['diferencia_tiempo_secs'].quantile(0.50))
    turnstile_maxs.append(filtered_turnstile_q_df['diferencia_tiempo_secs'].max())
    
    no_turnstile_obs.append(filtered_no_turnstile_q_df.count()[0])
    no_turnstile_means.append(filtered_no_turnstile_q_df['diferencia_tiempo_secs'].mean())
    no_turnstile_stds.append(filtered_no_turnstile_q_df['diferencia_tiempo_secs'].std())    
    no_turnstile_medians.append(filtered_no_turnstile_q_df['diferencia_tiempo_secs'].quantile(0.50))
    no_turnstile_maxs.append(filtered_no_turnstile_q_df['diferencia_tiempo_secs'].max())
    
    processed = processed + 1
    print('Number of already processed ddbb is ' + str(processed))
    del etapas_builder
    
toc = time.clock()  
toc-tic
# Out:
# Not found in turnstile database: 1614656
# Number of already processed ddbb is 1
# Not found in turnstile database: 1641812
# Number of already processed ddbb is 2
# Not found in turnstile database: 1689770
# Number of already processed ddbb is 3
# Not found in turnstile database: 1033091
# Number of already processed ddbb is 4
# Not found in turnstile database: 656097
# Number of already processed ddbb is 5
# Not found in turnstile database: 1776322
# Number of already processed ddbb is 6
# Not found in turnstile database: 1795630
# Number of already processed ddbb is 7
# Not found in turnstile database: 1079588
# Number of already processed ddbb is 8
# Not found in turnstile database: 622999
# Number of already processed ddbb is 9
# Not found in turnstile database: 1824234
# Number of already processed ddbb is 10
# Not found in turnstile database: 1832615
# Number of already processed ddbb is 11
# Not found in turnstile database: 1842842
# Number of already processed ddbb is 12
# Not found in turnstile database: 1821215
# Number of already processed ddbb is 13
# Not found in turnstile database: 1869848
# Number of already processed ddbb is 14
# Not found in turnstile database: 1087526
# Number of already processed ddbb is 15
# Not found in turnstile database: 645259
# Number of already processed ddbb is 16
# Not found in turnstile database: 622038
# Number of already processed ddbb is 17
# Not found in turnstile database: 1094159
# Number of already processed ddbb is 18
# Not found in turnstile database: 664623
# Number of already processed ddbb is 19
# Not found in turnstile database: 101951
# Number of already processed ddbb is 20
# Not found in turnstile database: 1829611
# Number of already processed ddbb is 21
# Not found in turnstile database: 1889530
# Number of already processed ddbb is 22
# Not found in turnstile database: 596016
# Number of already processed ddbb is 23
# Not found in turnstile database: 701753
# Number of already processed ddbb is 24
# Not found in turnstile database: 571269
# Number of already processed ddbb is 25
# Not found in turnstile database: 1793
# Number of already processed ddbb is 26
# Not found in turnstile database: 1869904
# Number of already processed ddbb is 27
# Not found in turnstile database: 335241
# Number of already processed ddbb is 28
# Not found in turnstile database: 1716855
# Number of already processed ddbb is 29
# Not found in turnstile database: 1131341
# Number of already processed ddbb is 30
# Not found in turnstile database: 629980
# Number of already processed ddbb is 31
# Not found in turnstile database: 1798424
# Number of already processed ddbb is 32
# Not found in turnstile database: 1820507
# Number of already processed ddbb is 33
# Not found in turnstile database: 1819403
# Number of already processed ddbb is 34
# Not found in turnstile database: 1860878
# Number of already processed ddbb is 35
# Not found in turnstile database: 1117796
# Number of already processed ddbb is 36
# Not found in turnstile database: 693103
# Number of already processed ddbb is 37
# Not found in turnstile database: 463308
# Number of already processed ddbb is 38
# Not found in turnstile database: 1868965
# Number of already processed ddbb is 39
# Not found in turnstile database: 1887908
# Number of already processed ddbb is 40
# Not found in turnstile database: 1878050
# Number of already processed ddbb is 41
# Not found in turnstile database: 1152530
# Number of already processed ddbb is 42
# Not found in turnstile database: 624912
# Number of already processed ddbb is 43
# Not found in turnstile database: 1800853
# Number of already processed ddbb is 44
# Not found in turnstile database: 1820652
# Number of already processed ddbb is 45
# Not found in turnstile database: 605491
# Number of already processed ddbb is 46
# Not found in turnstile database: 1810311
# Number of already processed ddbb is 47
# Not found in turnstile database: 1820128
# Number of already processed ddbb is 48
# Not found in turnstile database: 1806047
# Number of already processed ddbb is 49
# Not found in turnstile database: 1062678
# Number of already processed ddbb is 50
# Not found in turnstile database: 609616
# Number of already processed ddbb is 51
# Not found in turnstile database: 1878058
# Number of already processed ddbb is 52
# Not found in turnstile database: 1656973
# Number of already processed ddbb is 53
# Not found in turnstile database: 1812678
# Number of already processed ddbb is 54
# Not found in turnstile database: 1106546
# Number of already processed ddbb is 55
# Not found in turnstile database: 663085
# Number of already processed ddbb is 56
# Not found in turnstile database: 1787265
# Number of already processed ddbb is 57
# Not found in turnstile database: 1805951
# Number of already processed ddbb is 58
# Not found in turnstile database: 1836651
# Number of already processed ddbb is 59
# Not found in turnstile database: 1762627
# Number of already processed ddbb is 60
# Not found in turnstile database: 1816574
# Number of already processed ddbb is 61
# Not found in turnstile database: 1097326
# Number of already processed ddbb is 62
# Not found in turnstile database: 635621
# Number of already processed ddbb is 63
# Not found in turnstile database: 483882
# Number of already processed ddbb is 64
# Not found in turnstile database: 16924
# Number of already processed ddbb is 65
# Not found in turnstile database: 517700
# Number of already processed ddbb is 66
# Not found in turnstile database: 1764405
# Number of already processed ddbb is 67
# Not found in turnstile database: 1476164
# Number of already processed ddbb is 68
# Not found in turnstile database: 888465
# Number of already processed ddbb is 69
# Not found in turnstile database: 591189
# Number of already processed ddbb is 70
# Not found in turnstile database: 1717418
# Number of already processed ddbb is 71
# Not found in turnstile database: 1742288
# Number of already processed ddbb is 72
# Not found in turnstile database: 1626346
# Number of already processed ddbb is 73
# Not found in turnstile database: 1762639
# Number of already processed ddbb is 74
# Not found in turnstile database: 1026119
# Number of already processed ddbb is 75
# Not found in turnstile database: 550644
# Number of already processed ddbb is 76
# Not found in turnstile database: 522356
# Number of already processed ddbb is 77
# Not found in turnstile database: 1752652
# Number of already processed ddbb is 78
# Not found in turnstile database: 1772651
# Number of already processed ddbb is 79
# Not found in turnstile database: 1819159
# Number of already processed ddbb is 80
# Not found in turnstile database: 1137553
# Number of already processed ddbb is 81
# Not found in turnstile database: 557772
# Number of already processed ddbb is 82
# Not found in turnstile database: 1820720
# Number of already processed ddbb is 83
# Not found in turnstile database: 1658359
# Number of already processed ddbb is 84
# Not found in turnstile database: 1784611
# Number of already processed ddbb is 85
# Not found in turnstile database: 1740278
# Number of already processed ddbb is 86
# Not found in turnstile database: 1782404
# Number of already processed ddbb is 87
# Not found in turnstile database: 1104904
# Number of already processed ddbb is 88
# Not found in turnstile database: 650681
# Number of already processed ddbb is 89
# Not found in turnstile database: 1721318
# Number of already processed ddbb is 90
# Not found in turnstile database: 1680579
# Number of already processed ddbb is 91
# Not found in turnstile database: 1679634
# Number of already processed ddbb is 92
# Not found in turnstile database: 1560500
# Number of already processed ddbb is 93
# Not found in turnstile database: 1662196
# Number of already processed ddbb is 94
# Not found in turnstile database: 795121
# Number of already processed ddbb is 95
# Not found in turnstile database: 592387
# Number of already processed ddbb is 96
# Not found in turnstile database: 1598721
# Number of already processed ddbb is 97
# Not found in turnstile database: 1637796
# Number of already processed ddbb is 98
# Not found in turnstile database: 1777113
# Number of already processed ddbb is 99
# Not found in turnstile database: 1819766
# Number of already processed ddbb is 100
# Not found in turnstile database: 1831502
# Number of already processed ddbb is 101
# Not found in turnstile database: 1856222
# Number of already processed ddbb is 102
# Not found in turnstile database: 1172000
# Number of already processed ddbb is 103
# Not found in turnstile database: 705670
# Number of already processed ddbb is 104
# Not found in turnstile database: 1876347
# Number of already processed ddbb is 105
# Not found in turnstile database: 1867643
# Number of already processed ddbb is 106
# Not found in turnstile database: 1707189
# Number of already processed ddbb is 107
# Not found in turnstile database: 1081146
# Number of already processed ddbb is 108
# Not found in turnstile database: 584930
# Number of already processed ddbb is 109
# Not found in turnstile database: 1538951
# Number of already processed ddbb is 110
# Not found in turnstile database: 716738
# Number of already processed ddbb is 111
# Not found in turnstile database: 1873694
# Number of already processed ddbb is 112
# Not found in turnstile database: 1888514
# Number of already processed ddbb is 113
# Not found in turnstile database: 1106433
# Number of already processed ddbb is 114
# Not found in turnstile database: 665660
# Number of already processed ddbb is 115
# Not found in turnstile database: 1876590
# Number of already processed ddbb is 116
# Not found in turnstile database: 1877006
# Number of already processed ddbb is 117
# Not found in turnstile database: 1864219
# Number of already processed ddbb is 118
# Not found in turnstile database: 1842523
# Number of already processed ddbb is 119
# Not found in turnstile database: 1885813
# Number of already processed ddbb is 120
# Not found in turnstile database: 1132266
# Number of already processed ddbb is 121
# Not found in turnstile database: 614693
# Number of already processed ddbb is 122
# 2418.671880731697

# %% [markdown]
# * Summarizing

# %%
dates = [dt.datetime.strptime(x, "%Y-%m-%d").date() for x in dates]

# %%
summary_descriptives = pd.DataFrame(
    {'date': dates,
     'total_raw_trx': total_raw_trx,
     'total_trx': total_trx,
     'total_turns_trx': total_turns_trx,
     'total_no_turns_trx': total_no_turns_trx,
     'turnstile_obs':turnstile_obs,
     'turnstile_means': turnstile_means,
     'turnstile_stds': turnstile_stds,
     'turnstile_medians': turnstile_medians,
     'turnstile_maxs': turnstile_maxs,
     'no_turnstile_obs': no_turnstile_obs,
     'no_turnstile_means': no_turnstile_means,
     'no_turnstile_stds': no_turnstile_stds,
     'no_turnstile_medians': no_turnstile_medians,
     'no_turnstile_maxs': no_turnstile_maxs})

# %%
cols = ['date','total_raw_trx','total_trx','total_turns_trx','total_no_turns_trx',
        'turnstile_obs','turnstile_means','turnstile_stds','turnstile_medians','turnstile_maxs',
        'no_turnstile_obs','no_turnstile_means','no_turnstile_stds', 'no_turnstile_medians', 'no_turnstile_maxs']
summary_descriptives = summary_descriptives[cols]

# %% [markdown]
# * Checking

# %%
summary_descriptives
# Out:
#            date  total_raw_trx  total_trx  total_turns_trx  \
# 0    2017-03-01        2329229    2210399            48762
# 101           3.780668                   3.0               26.0
# 102           3.625146                   3.0               25.0
# 103           3.690041                   3.0               25.0
# 104           3.626155                   3.0               25.0
# 105           3.620812                   3.0               25.0
# 106           3.788109                   3.0               26.0
# 107           3.605587                   3.0               25.0
# 108           3.682942                   3.0               26.0
# 109           3.765567                   3.0               26.0
# 110           3.567856                   3.0               25.0
# 111           3.628027                   3.0               25.0
# 112           3.639169                   3.0               25.0
# 113           3.562705                   3.0               25.0
# 114           3.599946                   3.0               25.0
# 115           3.527694                   3.0               24.0
# 116           3.603983                   3.0               25.0
# 117           3.626909                   3.0               25.0
# 118           3.611687                   3.0               25.0
# 119           3.752302                   3.0               26.0
# 120           3.567411                   3.0               25.0
# 121           3.609601                   3.0               25.0
#
# [122 rows x 15 columns]

# %%
summary_descriptives[summary_descriptives['turnstile_means']>15]
# Out:
#           date  total_raw_trx  total_trx  total_turns_trx  total_no_turns_trx  \
# 19  2017-04-10         148909     147128             4482              113529
# 25  2017-04-17           2693       2661              113                2009
#
#     turnstile_obs  turnstile_means  turnstile_stds  turnstile_medians  \
# 19            865        21.393064       26.325341               12.0
# 25              1     12100.000000             NaN            12100.0
#
#     turnstile_maxs  no_turnstile_obs  no_turnstile_means  no_turnstile_stds  \
# 19           194.0             20580           16.341934          32.217150
# 25         12100.0                33         6667.090909       10894.966924
#
#     no_turnstile_medians  no_turnstile_maxs
# 19                   7.0              521.0
# 25                  10.0            34081.0

# %% [markdown]
# * Plotting

# %%
colors = [(85,98,112),(78,205,196),(199,244,100),(255,107,107),(196,77,88)]
for i in range(len(colors)):
    r, g, b = colors[i]  
    colors[i] = (r / 255., g / 255., b / 255.)

# %%
outlier_1 = dt.date(2017,4,10)
outlier_2 = dt.date(2017,4,17)

new_dates = [x for x in dates if ((x!=outlier_1)&(x!=outlier_2))]                                  
new_turnstile_means = [x for x in turnstile_means if x<15]
new_no_turnstile_means = [x for x in no_turnstile_means if x<15]

fig, ax_1 = plt.subplots()
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d/%m/%Y'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())

ax_1.plot(new_dates,new_turnstile_means, color = colors [3], label='2017 turnstiles')
ax_1.plot(new_dates,new_no_turnstile_means, color = colors [0], label='no turnstiles')

fig.autofmt_xdate()
ax_1.legend()
ax_1.set_title('Mean of time intervals evolution')

#plt.savefig('C:/Users/Tesista/Desktop/Evasion/03_report/02_Figs/6_meansEvolutionInTime.pdf')

# %%
outlier_1 = dt.date(2017,4,10)
outlier_2 = dt.date(2017,4,17)

new_dates = [x for x in dates if ((x!=outlier_1)&(x!=outlier_2))]                                  
new_turnstile_means = [x for x in turnstile_means if x<15]
new_no_turnstile_means = [x for x in no_turnstile_means if x<15]

fig, ax_1 = plt.subplots()
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d/%m/%Y'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())

ax_1.plot(dates,total_raw_trx, color = colors[1], label='total-trx')


fig.autofmt_xdate()
#ax_1.legend()
ax_1.set_title('Total trx in time')

#plt.savefig('C:/Users/Tesista/Desktop/Evasion/03_report/02_Figs/6_meansEvolutionInTime.pdf')
