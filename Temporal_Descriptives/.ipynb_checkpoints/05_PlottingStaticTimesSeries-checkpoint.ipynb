# %% [markdown]
# ## Plotting times series - static

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter
import numpy as np
import datetime as dt
import time
# Out:
# <style>.container { width:80% !important; }</style>

# %%
from Utils import TransantiagoConstants
DTPM_TRXDir = TransantiagoConstants.DTPM_TRXDir

# %% [markdown]
# * Defining global things

# %%
colors = [(76, 181, 245),(183, 184, 182),(52, 103, 92),(179, 193, 0)]
for i in range(len(colors)):
    r, g, b = colors[i]  
    colors[i] = (r / 255., g / 255., b / 255.)

# %%
def millions(x, pos):
    'The two args are the value and tick position'
    return '%1.1fM' % (x*1e-6)

# %% [markdown]
# * Defining functions to plot

# %%
def monthlyPlotter(save_figure):
    
    monthly_input_path = os.path.join(DTPM_TRXDir,'1_MONTHLY/monthly_summary.csv')
    monthly_trx = pd.read_csv(monthly_input_path,sep=';',encoding='latin-1', index_col=0)
    
    months_values = pd.date_range(start='2015-01',end='2018-01',freq='M').values
    no_turnstile_values = list(map(int, monthly_trx['pn_SUM_TRX_no_t'].values))
    three_turnstile_values = list(map(int,monthly_trx['pn_SUM_TRX_3t'].values))
    butterfly_turnstile_values = list(map(int,monthly_trx['pn_SUM_TRX_tm'].values))
    zp_values = list(map(int,monthly_trx['zp_SUM_TRX'].values))
    ratio_butterfly_turnstile_values = list(map(int,monthly_trx['ratio_tm'].values))
    
    formatter = FuncFormatter(millions)
    
    labels = ["ZP", "S/T", "C/T3", "C/TM"]
    fig, ax = plt.subplots()
    ax.stackplot(months_values, zp_values, no_turnstile_values , three_turnstile_values , butterfly_turnstile_values , labels = labels , colors=colors)
    ax.legend(loc=2)
    ax.set_title('Transacciones por mes, 2015 a 2017')
    ax.set_ylabel('Transacciones')
    ax.yaxis.set_major_formatter(formatter)
    ax.set_xlabel('Mes del año')
    fig.autofmt_xdate()
    
    ax_1 = ax.twinx()
    ax_1.plot(months_values, ratio_butterfly_turnstile_values, 'ro-', color = 'black',  label = '% Exp.')
    ax_1.set_ylabel('% Expediciones con torniquete mariposa')
    ax_1.legend(loc=4)
    ax_1.set_ylim(0, 100)

    if save_figure:
        plt.savefig('C:/Users/leoca_000/Desktop/Evasion/03_report/02_Figs/5_trxOverTimeByMonth_all.pdf')
        
    plt.show()

# %%
def monthlyByUnPlotter(UN, save_figure):
        
    monthly_input_path = os.path.join(DTPM_TRXDir,'2_MONTHLY_UN/' + UN + '/' + UN + '_summary.csv')
    monthly_trx = pd.read_csv(monthly_input_path,sep=';',encoding='latin-1', index_col=0)
    
    months_values = pd.date_range(start='2015-01',end='2018-01',freq='M').values
    no_turnstile_values = list(map(int, monthly_trx['pn_SUM_TRX_no_t'].values))
    three_turnstile_values = list(map(int,monthly_trx['pn_SUM_TRX_3t'].values))
    butterfly_turnstile_values = list(map(int,monthly_trx['pn_SUM_TRX_tm'].values))
    zp_values = list(map(int,monthly_trx['zp_SUM_TRX'].values))
    ratio_butterfly_turnstile_values = list(map(int,monthly_trx['ratio_tm'].values))
    
    formatter = FuncFormatter(millions)
    
    labels = ["ZP", "S/T", "C/T3", "C/TM"]
    fig, ax = plt.subplots()
    ax.stackplot(months_values, zp_values, no_turnstile_values , three_turnstile_values , butterfly_turnstile_values , labels = labels , colors=colors)
    ax.legend(loc=2)
    ax.set_title('Transacciones por mes, ' + UN + ', 2015 a 2017')
    ax.set_ylabel('Transacciones')
    ax.yaxis.set_major_formatter(formatter)
    ax.set_xlabel('Mes del año')
    fig.autofmt_xdate()
    
    ax_1 = ax.twinx()
    ax_1.plot(months_values, ratio_butterfly_turnstile_values, 'ro-', color = 'black',  label = '% Exp.')
    ax_1.set_ylabel('% Expediciones con torniquete mariposa')
    ax_1.legend(loc=3)
    ax_1.set_ylim(0, 100)

    if save_figure:
        plt.savefig('C:/Users/leoca_000/Desktop/Evasion/03_report/02_Figs/5_trxOverTimeByMonth' + UN + '.pdf')
        
    plt.show()

# %%
def dailyPlotter(save_figure):
    
    daily_input_path = os.path.join(DTPM_TRXDir,'3_DAILY/daily_summary.csv')
    daily_trx = pd.read_csv(daily_input_path,sep=';',encoding='latin-1', index_col=0)
    
    days_values = pd.date_range(start='2015-01-01',end='2017-12-31',freq='D').values
    no_turnstile_values = list(map(int, daily_trx['pn_SUM_TRX_no_t'].values))
    three_turnstile_values = list(map(int,daily_trx['pn_SUM_TRX_3t'].values))
    butterfly_turnstile_values = list(map(int,daily_trx['pn_SUM_TRX_tm'].values))
    zp_values = list(map(int,daily_trx['zp_SUM_TRX'].values))
    ratio_butterfly_turnstile_values = list(map(int,daily_trx['ratio_tm'].values))
    
    formatter = FuncFormatter(millions)
    
    labels = ["ZP", "S/T", "C/T3", "C/TM"]
    fig, ax = plt.subplots()
    ax.stackplot(days_values, zp_values, no_turnstile_values , three_turnstile_values , butterfly_turnstile_values , labels = labels , colors=colors)
    ax.legend(loc=2)
    ax.set_title('Transacciones por mes, 2015 a 2017')
    ax.set_ylabel('Transacciones')
    ax.yaxis.set_major_formatter(formatter)
    ax.set_xlabel('Mes del año')
    fig.autofmt_xdate()
    
    ax_1 = ax.twinx()
    ax_1.plot(days_values, ratio_butterfly_turnstile_values, color = 'black',  label = '% Exp.')
    ax_1.set_ylabel('% Expediciones con torniquete mariposa')
    ax_1.legend(loc=4)
    ax_1.set_ylim(0, 100)

    if save_figure:
        plt.savefig('C:/Users/leoca_000/Desktop/Evasion/03_report/02_Figs/5_trxOverTimeByDay_all.pdf')
        
    plt.show()

# %%
def dailyByUnPlotter(UN, save_figure):
    daily_input_path = os.path.join(DTPM_TRXDir,'4_DAILY_UN/' + UN + '/' + UN + '_summary.csv')
    daily_trx = pd.read_csv(daily_input_path,sep=';',encoding='latin-1', index_col=0)
    
    days_values = pd.date_range(start='2015-01-01',end='2017-12-31',freq='D').values
    no_turnstile_values = list(map(int, daily_trx['pn_SUM_TRX_no_t'].values))
    three_turnstile_values = list(map(int,daily_trx['pn_SUM_TRX_3t'].values))
    butterfly_turnstile_values = list(map(int,daily_trx['pn_SUM_TRX_tm'].values))
    zp_values = list(map(int,daily_trx['zp_SUM_TRX'].values))
    ratio_butterfly_turnstile_values = list(map(int,daily_trx['ratio_tm'].values))
    
    formatter = FuncFormatter(millions)
    
    labels = ["ZP", "S/T", "C/T3", "C/TM"]
    fig, ax = plt.subplots()
    ax.stackplot(days_values, zp_values, no_turnstile_values , three_turnstile_values , butterfly_turnstile_values , labels = labels , colors=colors)
    ax.legend(loc=2)
    ax.set_title('Transacciones por mes, ' + UN + ', 2015 a 2017')
    ax.set_ylabel('Transacciones')
    ax.yaxis.set_major_formatter(formatter)
    ax.set_xlabel('Mes del año')
    fig.autofmt_xdate()
    
    ax_1 = ax.twinx()
    ax_1.plot(days_values, ratio_butterfly_turnstile_values, color = 'black',  label = '% Exp.')
    ax_1.set_ylabel('% Expediciones con torniquete mariposa')
    ax_1.legend(loc=3)
    ax_1.set_ylim(0, 100)   

    if save_figure:
        plt.savefig('C:/Users/leoca_000/Desktop/Evasion/03_report/02_Figs/5_trxOverTimeByDay' + UN + '.pdf')
        
    plt.show()

# %% [markdown]
# * Plotting

# %%
monthlyPlotter(True)

# %%
monthlyByUnPlotter('U1',True)

# %%
monthlyByUnPlotter('U2',True)

# %%
monthlyByUnPlotter('U3',True)

# %%
monthlyByUnPlotter('U4',True)

# %%
monthlyByUnPlotter('U5',True)

# %%
monthlyByUnPlotter('U6',True)

# %%
monthlyByUnPlotter('U7',True)

# %%
dailyPlotter(True)

# %%
dailyByUnPlotter('U1',True)

# %%
dailyByUnPlotter('U2',True)

# %%
dailyByUnPlotter('U3',True)

# %%
dailyByUnPlotter('U4',True)

# %%
dailyByUnPlotter('U5',True)

# %%
dailyByUnPlotter('U6',True)

# %%
dailyByUnPlotter('U7',True)
